# %% [markdown]
# # Practice
#
# Scratch notebook for experimenting with the backend (config, DB, agents, etc.).

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

BACKEND = ROOT / "backend"
if str(BACKEND) not in sys.path:
    sys.path.insert(0, str(BACKEND))

# from app.config import settings
from app.services.llm import get_llm_model
from app.services.search import get_search_tool
from app.services.prompts import RESEARCH_SYSTEM_PROMPT

# %%
llm = get_llm_model()
llm.invoke("Hello")
# Out:
# AIMessage(content='Hello! How can I help you today? 😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 9, 'total_tokens': 21, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen/qwen3-next-80b-a3b-instruct', 'system_fingerprint': None, 'id': 'chatcmpl-b55381c581f27344', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ee9b8-df23-7710-be1e-4242f9c929e3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 12, 'total_tokens': 21, 'input_token_details': {}, 'output_token_details': {}})

# %%
search_tool = get_search_tool()
search_tool.invoke("IPL 2026")
# Out:
# [{'title': '2026 Indian Premier League - Wikipedia',
#   'url': 'https://en.wikipedia.org/wiki/2026_Indian_Premier_League',
# ...

# %%
from deepagents import create_deep_agent

# %%
agent = create_deep_agent(
  model=llm,
  tools=[search_tool],
  system_prompt=RESEARCH_SYSTEM_PROMPT
)

# %%
from langchain_core.messages import HumanMessage


resp = agent.invoke({
  "messages":[HumanMessage("Compare Amazon Textract, Azure Document Intelligence, and Google Document AI for processing 400-page annual reports.")]
})

# %%
x = resp['messages'][-1]

# %%
print(x.content)
# Out:
# ## Summary
# For processing 400-page annual reports, Azure Document Intelligence emerges as the most robust solution due to its superior table and structured data extraction accuracy, seamless integration with Microsoft ecosystems, and strong support for enterprise compliance. Amazon Textract offers reliable performance within AWS environments and excels in form and query-based extraction, but lags in complex table parsing. Google Document AI provides broad language support and a powerful ecosystem but suffers from strict page limits on synchronous requests and inconsistent table extraction accuracy, making it less suitable for large financial documents. All three services support batch processing for large files, but Azure’s combination of accuracy, scalability, and enterprise features makes it the top choice for annual reports.
#
# ## Key Findings
# ...
